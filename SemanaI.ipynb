# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import csv
# %matplotlib inline
from numpy import genfromtxt

# %%
Data = pd.read_csv("Machote de datos.csv", encoding = "ISO-8859-1")

# %%
Data
# Out:
#        Vehiculo Fecha de Inicio Inicio (Hora) Hora de parada  \
# 0         10005        2/4/2018      20:35:19       20:38:10
# 1         10005        3/4/2018       4:28:21        4:46:56
# 2         10005        3/4/2018       6:23:38        6:24:13
# 3         10005        4/4/2018        4:12:7        4:51:49
# 4         10005        7/4/2018      19:22:36       19:23:13
# 5         10005        8/4/2018       18:1:43       18:10:31
# 6         10005        8/4/2018      21:46:16       21:48:11
# 7         10006        7/4/2018       13:9:14       13:11:58
# 8         10006        7/4/2018      13:13:16       13:14:33
# 9         10006        7/4/2018      13:14:49        14:7:40
# 10        10006        8/4/2018      12:15:54       12:34:35
# 11        10007        3/4/2018       6:26:12        6:37:26
# 12        10007        4/4/2018      11:38:25       11:44:53
# 13        10009        3/4/2018       6:27:31        6:28:10
# ...

# %%
XData = np.genfromtxt("Machote de datos.csv", delimiter = ',')
DataX = XData[1: ,4:5]
print(DataX)
# Out:
# [[ 0.        ]
#  [ 0.        ]
#  [ 0.        ]
#  ...
#  [29.46350793]
#  [23.29050946]
#  [23.26402988]]
